# %% [markdown]
# <a href="https://colab.research.google.com/github/KKPL59/computer-vision-course/blob/main/Podstawowe_operacje_na_obrazie_cz_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np

# %%
logo = cv2.imread(filename="python.png")
cv2_imshow(logo)
# Out:
# <PIL.Image.Image image mode=RGB size=960x280 at 0x7F5563181490>

# %%
#filtr krawędzi pionowych 
kernel_vertical = np.array([[-1,0,1], [-2,0,2], [-1,0,1]])
output = cv2.filter2D(src=logo, ddepth=-1, kernel=kernel_vertical)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=960x280 at 0x7F555EEA0C10>

# %%
#filtr krawędzi poziomych 
kernel_horizontal = np.array([[-1,-2,-1], [0,0,0], [1,2,1]])
output = cv2.filter2D(src=logo, ddepth=-1, kernel=kernel_horizontal)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=960x280 at 0x7F555ED9BC90>

# %% [markdown]
# ###zwykle najpierw przekształca sie obraz na grayscale a dopiero później zaznacza krawędzie

# %%
logo = cv2.imread("python.png", flags=cv2.IMREAD_GRAYSCALE)
cv2_imshow(logo)
# Out:
# <PIL.Image.Image image mode=L size=960x280 at 0x7F55631542D0>

# %%
cv2_imshow(cv2.filter2D(src=logo, ddepth=-1, kernel=kernel_vertical))
# Out:
# <PIL.Image.Image image mode=L size=960x280 at 0x7F555EE5D8D0>

# %%
cv2_imshow(cv2.filter2D(src=logo, ddepth=-1, kernel=kernel_horizontal))
# Out:
# <PIL.Image.Image image mode=L size=960x280 at 0x7F555EDAE350>

# %% [markdown]
# ###Filtry, którymi się posdługujemy są znane pod nazwą Sobel. Biblioteka opencv dostarcza także gotową funkcję Sobel

# %%
cv2_imshow(cv2.Sobel(src=logo, ddepth=cv2.CV_64F, dx=0, dy=1, ksize=5))
# Out:
# <PIL.Image.Image image mode=L size=960x280 at 0x7F555ED90210>

# %% [markdown]
# ###Innym znanym filtrem, który pozwala wykryć krawędzie jest Laplacian

# %%
cv2_imshow(cv2.Laplacian(src=logo, ddepth=cv2.CV_64F))
# Out:
# <PIL.Image.Image image mode=L size=960x280 at 0x7F555ED56590>

# %% [markdown]
# ###canny

# %%
bear = cv2.imread(filename="bear.jpg")
cv2_imshow(cv2.Laplacian(src=bear, ddepth=cv2.CV_64F))
# Out:
# <PIL.Image.Image image mode=RGB size=586x480 at 0x7F555EE3F790>

# %%
#im mniejszy próg(threshold), tym więcej krawędzi zostanie wykrytych 
cv2_imshow(cv2.Canny(image=logo, threshold1=0, threshold2=0))
# Out:
# <PIL.Image.Image image mode=L size=960x280 at 0x7F555ED9EE10>

# %%
cv2_imshow(cv2.Canny(image=logo, threshold1=100, threshold2=100))
# Out:
# <PIL.Image.Image image mode=L size=960x280 at 0x7F555ED4CF50>

# %% [markdown]
# ###erozja

# %%
logo = cv2.imread(filename="python.png")

# %%
kernel = np.ones((5,5), np.uint8)
cv2_imshow(cv2.erode(src=logo, kernel=kernel, iterations=1))
# Out:
# <PIL.Image.Image image mode=RGB size=960x280 at 0x7F555ED01510>

# %%
cv2_imshow(cv2.dilate(src=logo, kernel=kernel, iterations=1))
# Out:
# <PIL.Image.Image image mode=RGB size=960x280 at 0x7F555D4D3A50>
